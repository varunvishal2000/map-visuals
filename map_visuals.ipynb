# %%
import matplotlib.pyplot as plt
import geopandas as gpd
import pandas as pd

# %%
# Define data
states = ["Uttar Pradesh", "Tamil Nadu", "Andhra Pradesh", "Karnataka", "Gujarat", 
          "Maharashtra", "Rajasthan", "West Bengal", "Telangana", "Uttarakhand",
          "Jharkhand", "Madhya Pradesh", "Delhi", "Punjab", "Bihar"]
tourist_visits = [3179.136, 2185.848, 1927.67, 1824.132, 1358.113,
                  1112.976, 1083.282, 845.422, 607.484, 546.426,
                  382.844, 358.488, 271.862, 260.894, 253.304]
percentages = [18.4, 12.6, 11.1, 10.5, 7.8, 6.4, 6.3, 4.9, 3.5, 3.2,
               2.2, 2.0, 1.6, 1.5, 1.4]

# %%
fp = r'./Maps_with_python/india-polygon.shp'
map_df = gpd.read_file(fp)
map_df_copy = gpd.read_file(fp)
map_df.head(30)
# Out:
#       id                        st_nm  \
# 0   None  Andaman and Nicobar Islands
# 1   None            Arunachal Pradesh
# 2   None                        Assam
# 3   None                        Bihar
# 4   None                   Chandigarh
# 5   None                 Chhattisgarh
# 6   None       Dadra and Nagar Haveli
# 7   None                Daman and Diu
# 8   None                          Goa
# 9   None                      Gujarat
# 10  None                      Haryana
# 11  None             Himachal Pradesh
# 12  None                    Jharkhand
# 13  None                    Karnataka
# 14  None                       Kerala
# 15  None                  Lakshadweep
# 16  None               Madhya Pradesh
# 17  None                  Maharashtra
# 18  None                      Manipur
# 19  None                    Meghalaya
# 20  None                      Mizoram
# 21  None                     Nagaland
# 22  None                        Delhi
# ...

# %%
map_df.plot()
# Out:
# <AxesSubplot:>

# %%
data_dict = {"states": ["Uttar Pradesh", "Tamil Nadu", "Andhra Pradesh", "Karnataka", "Gujarat", 
          "Maharashtra", "Rajasthan", "West Bengal", "Telangana", "Uttarakhand",
          "Jharkhand", "Madhya Pradesh", "Delhi", "Punjab", "Bihar"],
            "tourist_visits": [3179.136, 2185.848, 1927.67, 1824.132, 1358.113,
                  1112.976, 1083.282, 845.422, 607.484, 546.426,
                  382.844, 358.488, 271.862, 260.894, 253.304],
            "percentages": [18.4, 12.6, 11.1, 10.5, 7.8, 6.4, 6.3, 4.9, 3.5, 3.2,
               2.2, 2.0, 1.6, 1.5, 1.4]}

# %%
state_df = pd.DataFrame(data_dict)

# %%
state_df
# Out:
#             states  tourist_visits  percentages
# 0    Uttar Pradesh        3179.136         18.4
# 1       Tamil Nadu        2185.848         12.6
# 2   Andhra Pradesh        1927.670         11.1
# 3        Karnataka        1824.132         10.5
# 4          Gujarat        1358.113          7.8
# 5      Maharashtra        1112.976          6.4
# 6        Rajasthan        1083.282          6.3
# 7      West Bengal         845.422          4.9
# 8        Telangana         607.484          3.5
# 9      Uttarakhand         546.426          3.2
# 10       Jharkhand         382.844          2.2
# 11  Madhya Pradesh         358.488          2.0
# 12           Delhi         271.862          1.6
# 13          Punjab         260.894          1.5
# 14           Bihar         253.304          1.4

# %%
merged = map_df.set_index('st_nm').join(state_df.set_index('states'))

# %%
merged
# Out:
#                              id  \
# st_nm
# Andaman and Nicobar Islands   0
# Arunachal Pradesh             0
# Assam                         0
# Bihar                         0
# Chandigarh                    0
# Chhattisgarh                  0
# Dadra and Nagar Haveli        0
# Daman and Diu                 0
# Goa                           0
# Gujarat                       0
# Haryana                       0
# Himachal Pradesh              0
# Jharkhand                     0
# Karnataka                     0
# Kerala                        0
# Lakshadweep                   0
# Madhya Pradesh                0
# Maharashtra                   0
# Manipur                       0
# Meghalaya                     0
# Mizoram                       0
# Nagaland                      0
# Delhi                         0
# Puducherry                    0
# Punjab                        0
# Rajasthan                     0
# Sikkim                        0
# Tamil Nadu                    0
# ...

# %%
merged["tourist_visits"] = merged["tourist_visits"].fillna(0)

# %%
merged.plot(column="tourist_visits", legend="true")
# Out:
# <AxesSubplot:>
